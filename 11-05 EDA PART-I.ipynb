# %% [markdown]
# # EDA on Marketing_Analysis.csv File

# %%
import pandas as pd

# %%
# Reading a flat file in pandas dataframe

Marketing_Data = pd.read_csv(r'C:\Users\hp\Desktop\ML-Manoj sir\Marketing_Analysis.csv',skiprows=2)  # Or we can use header = 2 inplace of skiprows=2

# %%
Marketing_Data
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
type(Marketing_Data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Displaying Data
# only top 5 rows
Marketing_Data.head(n=3)   # .head(3)
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# 1     -1         0  unknown       no
# 2     -1         0  unknown       no

# %%
# only bottom 5 rows
Marketing_Data.tail(n=3)    # .tail(3)
# Out:
#        customerid   age  salary  balance  marital                  jobedu  \
# 45208       45209  72.0   55000     5715  married       retired,secondary
# 45209       45210  57.0   20000      668  married   blue-collar,secondary
# 45210       45211  37.0  120000     2971  married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# 45208      yes      no      no   no   cellular   17  nov, 2017
# 45209      yes      no      no   no  telephone   17  nov, 2017
# 45210      yes      no      no   no   cellular   17  nov, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 45208  18.7833333333333 min         5    184         3  success      yes
# 45209  8.46666666666667 min         4     -1         0  unknown       no
# 45210  6.01666666666667 min         2    188        11    other       no

# %%
# displaying random rows
Marketing_Data.sample()   # By default it gives only one random value
# Out:
#       customerid   age  salary  balance  marital               jobedu  \
# 2579        2580  44.0  100000      126  married  management,tertiary
#
#      targeted default housing loan  contact  day      month duration  \
# 2579      yes      no     yes   no  unknown   13  may, 2017   92 sec
#
#       campaign  pdays  previous poutcome response
# 2579         1     -1         0  unknown       no

# %%
Marketing_Data.sample(n=5)   # .sample(5)
# Out:
#        customerid   age  salary  balance   marital               jobedu  \
# 10377       10378  47.0   16000     1453  divorced  housemaid,secondary
# 16690       16691  29.0  100000     1022   married  management,tertiary
# 38844       38845  22.0   70000      344    single   services,secondary
# 42767       42768  52.0   70000      659   married   services,secondary
# 16389       16390  53.0  100000      267   married  management,tertiary
#
#       targeted default housing loan    contact  day      month  \
# 10377      yes      no      no   no    unknown   12  jun, 2017
# 16690      yes      no     yes   no   cellular   24  jul, 2017
# 38844      yes      no     yes   no   cellular   18  may, 2017
# 42767      yes      no      no   no   cellular   28  jan, 2017
# 16389      yes      no     yes   no  telephone   23  jul, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 10377               303 sec         1     -1         0  unknown       no
# ...

# %%
# only rows 
data = {
    'name':['anjali','rani','nisha','radha','ruby','rishika'],
    'age':[17,18,19,20,21,18],
    'marks':[45,43,42,41,40,34]
    
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age  marks
# 0   anjali   17     45
# 1     rani   18     43
# 2    nisha   19     42
# 3    radha   20     41
# 4     ruby   21     40
# 5  rishika   18     34

# %%
df.head(n=-2)   # it remove two rows from bottom
# Out:
#      name  age  marks
# 0  anjali   17     45
# 1    rani   18     43
# 2   nisha   19     42
# 3   radha   20     41

# %%
df.tail(n=-2)  # it remove two rows from top
# Out:
#       name  age  marks
# 2    nisha   19     42
# 3    radha   20     41
# 4     ruby   21     40
# 5  rishika   18     34

# %%
# shape
x,y=Marketing_Data.shape
print('Rows = ',x,'\n\nColumns= ',y)
# Out:
# Rows =  45211
#
# Columns=  19

# %%
# or
print('Rows = ',Marketing_Data.shape[0],'\n\nColumns = ',Marketing_Data.shape[1])
# Out:
# Rows =  45211
#
# Columns =  19

# %%
# fstring
x,y = Marketing_Data.shape
print('Rows = {}, columns = {}'.format(x,y))
# Out:
# Rows = 45211, columns = 19

# %%
# size
Marketing_Data.size   # total number of element in DataFrame i.e rows X columns
# Out:
# 859009

# %%
# info
Marketing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %%
# Describe
Marketing_Data.describe()
# Out:
#          customerid           age         salary        balance           day  \
# count  45211.000000  45191.000000   45211.000000   45211.000000  45211.000000
# mean   22606.000000     40.935651   57006.171065    1362.272058     15.806419
# std    13051.435847     10.619198   32085.718415    3044.765829      8.322476
# min        1.000000     18.000000       0.000000   -8019.000000      1.000000
# 25%    11303.500000     33.000000   20000.000000      72.000000      8.000000
# 50%    22606.000000     39.000000   60000.000000     448.000000     16.000000
# 75%    33908.500000     48.000000   70000.000000    1428.000000     21.000000
# max    45211.000000     95.000000  120000.000000  102127.000000     31.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
# columns

Marketing_Data.columns
# Out:
# Index(['customerid', 'age', 'salary', 'balance', 'marital', 'jobedu',
#        'targeted', 'default', 'housing', 'loan', 'contact', 'day', 'month',
#        'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'response'],
#       dtype='object')

# %%
Marketing_Data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
Marketing_Data.drop('customerid',axis=1)
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
Marketing_Data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
# For permanent deleting the column we use  inplace=True
Marketing_Data.drop('customerid',axis=1, inplace=True)

# %%
Marketing_Data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...
